# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhawaldwivedi/Data-analytics/blob/main/Da%20wd%2018/python/Conditionals_in_python_da_wd_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = 12
if age>=18 :
  print("eligible")
else:
  print("not eligible")
# Out:
# not eligible

# %%
age = 28

if age<100 and age >=18:
  print('eligible')
elif age>0 and age<18 :
  print('not eligible')
else :
  print('invalid age')
# Out:
# eligible

# %%
# wap to check if a number is even or odd
n = int(input("enter the number "))
if n%2==0:
  print("even")
else :
  print("odd")
# Out:
# enter the number 65
# odd

# %%
# wap to check if number is divisible by 3 and 5 or not
n = int(input("enter the number "))
if n%3==0 and n%5==0:
  print('divisible by 3 and 5')
elif n%3==0 and n%5 != 0:
  print('divisible by 3 only')
elif n%3!=0 and n%5 == 0:
  print('divisible by 5 only')

else:
  print('not divisible')
# Out:
# enter the number 25
# divisible by 5 only

# %%
''' wap to check if a number is positive or negative if postive check if
 its even or odd'''
n = int(input("enter the number "))
if n>0:
  print('positive')
  if n%2==0:
    print('even')
  else :
    print('odd')
else:
  print('negative')
# Out:
# enter the number 26
# positive
# even

# %%
# wap to authentic a basic username and password
stored_username = 'user123'
stored_password = 'user@123'

username = input('enter username ')

if username == stored_username :
  password = input('enter password ')
  if password == stored_password :
    print('login successful')
  else :
    print('invalid password')
else :
  print('invalid username')
# Out:
# enter username user123
# enter password user@123
# login successful

# %%
# check if entered year is leap year or not
# 2024 , 2000 , 1900
year = int(input('enter a year '))
if (year%4==0 and year%100 != 0) or year%400==0:
  print('Leap year')
else :
  print('not a leap year')
# Out:
# enter a year 2000
# Leap year

# %%
# wap to find the largest of 3 numbers
a = int(input("enter the first number "))
b = int(input("enter the second number "))
c = int(input("enter the third number "))

if a > b and a > c:
  print(f'{a} is a is largest')
elif b>a and b>c :
  print(f'{b} is b is largest')
else :
  print(f'{c} is c is largest')
# Out:
# enter the first number 12
# enter the second number 13
# enter the third number 8
# 13 is b is largest

# %% [markdown]
# a   b   c
