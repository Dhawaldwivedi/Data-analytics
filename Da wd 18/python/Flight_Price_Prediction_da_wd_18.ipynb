# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhawaldwivedi/Data-analytics/blob/main/Da%20wd%2018/python/Flight_Price_Prediction_da_wd_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('/content/flight_price (1).xlsx')
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.shape
# Out:
# (10683, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662

# %%
# missing/ null values
df.isnull()
# Out:
#        Airline  Date_of_Journey  Source  Destination  Route  Dep_Time  \
# 0        False            False   False        False  False     False
# 1        False            False   False        False  False     False
# 2        False            False   False        False  False     False
# 3        False            False   False        False  False     False
# 4        False            False   False        False  False     False
# ...        ...              ...     ...          ...    ...       ...
# 10678    False            False   False        False  False     False
# 10679    False            False   False        False  False     False
# 10680    False            False   False        False  False     False
# 10681    False            False   False        False  False     False
# 10682    False            False   False        False  False     False
#
#        Arrival_Time  Duration  Total_Stops  Additional_Info  Price
# ...

# %%
# calculating the sum of null values in each column
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %% [markdown]
# **Treating null values**
#
# Case 1 - If the values are significantly less - prefer to remove the row
#
# Case 2 - If the values are slighlty higher but numerical - replace the null values with the mean
#
# Case 3 -  If the values are slighlty higher and numerical but contains outlier - median
#
# Case 4 - If the values are higher and categorical - Mode

# %%
# dropna  ( dropping the null values )
# inplace is used to drop in the same dataframe
df.dropna(subset = ['Route','Total_Stops'],inplace = True)

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %% [markdown]
# **Now our next step is to analyse the dataframe column wise so we start with the Airines**

# %% [markdown]
# # Airline

# %%
df['Airline']
# Out:
# 0             IndiGo
# 1          Air India
# 2        Jet Airways
# 3             IndiGo
# 4             IndiGo
#             ...
# 10678       Air Asia
# 10679      Air India
# 10680    Jet Airways
# 10681        Vistara
# 10682      Air India
# Name: Airline, Length: 10682, dtype: object

# %%
df['Airline'].unique()  # shows me the unique airlines
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
df['Airline'].nunique()  # shows the count of unique airline
# Out:
# 12

# %%
df['Airline'].value_counts()  # shows the count of each airline
# Out:
# Airline
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1751
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %% [markdown]
# # Date of Journey

# %%
df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662

# %%
df['Date_of_Journey'].str.split("/")
# Out:
# 0        [24, 03, 2019]
# 1         [1, 05, 2019]
# 2         [9, 06, 2019]
# 3        [12, 05, 2019]
# 4        [01, 03, 2019]
#               ...
# 10678     [9, 04, 2019]
# 10679    [27, 04, 2019]
# 10680    [27, 04, 2019]
# 10681    [01, 03, 2019]
# 10682     [9, 05, 2019]
# Name: Date_of_Journey, Length: 10682, dtype: object

# %%
# splitted the dates into days , months and years so that we can perform analysis easily
# converted the column to int from object using astype(int)
df['Days'] = df['Date_of_Journey'].str.split("/").str[0].astype(int)
df['Months'] = df['Date_of_Journey'].str.split("/").str[1].astype(int)
df['Year'] = df['Date_of_Journey'].str.split("/").str[2].astype(int)

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  Days  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897    24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662     1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882     9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218    12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302     1
#
#    Months  Year
# 0       3  2019
# 1       5  2019
# ...

# %%
del df['Date_of_Journey']

# %% [markdown]
# # Source and Destination

# %%
df.head(2)
# Out:
#      Airline    Source Destination                  Route Dep_Time  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price  Days  Months  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897    24       3
# 1         13:15   7h 25m     2 stops         No info   7662     1       5
#
#    Year
# 0  2019
# 1  2019

# %%
df['Source'].value_counts()
# Out:
# Source
# Delhi       4536
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: count, dtype: int64

# %%
df['Destination'].value_counts()
# Out:
# Destination
# Cochin       4536
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: count, dtype: int64

# %%
df['Source'].unique()
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %%
del df['Route']

# %% [markdown]
# # Dep_Time

# %%
df.head(2)
# Out:
#      Airline    Source Destination Dep_Time  Arrival_Time Duration  \
# 0     IndiGo  Banglore   New Delhi    22:20  01:10 22 Mar   2h 50m
# 1  Air India   Kolkata    Banglore    05:50         13:15   7h 25m
#
#   Total_Stops Additional_Info  Price  Days  Months  Year
# 0    non-stop         No info   3897    24       3  2019
# 1     2 stops         No info   7662     1       5  2019

# %%
# splitted the departure time into hours and minutes
df['Dep_hours'] = df['Dep_Time'].str.split(':').str[0].astype(int)
df['Dep_min'] = df['Dep_Time'].str.split(':').str[1].astype(int)

# %%
del df['Dep_Time']
df.head(2)
# Out:
#      Airline    Source Destination  Arrival_Time Duration Total_Stops  \
# 0     IndiGo  Banglore   New Delhi  01:10 22 Mar   2h 50m    non-stop
# 1  Air India   Kolkata    Banglore         13:15   7h 25m     2 stops
#
#   Additional_Info  Price  Days  Months  Year  Dep_hours  Dep_min
# 0         No info   3897    24       3  2019         22       20
# 1         No info   7662     1       5  2019          5       50

# %% [markdown]
# # Arrival Time

# %%
df.head(2)
# Out:
#      Airline    Source Destination  Arrival_Time Duration Total_Stops  \
# 0     IndiGo  Banglore   New Delhi  01:10 22 Mar   2h 50m    non-stop
# 1  Air India   Kolkata    Banglore         13:15   7h 25m     2 stops
#
#   Additional_Info  Price  Days  Months  Year  Dep_hours  Dep_min
# 0         No info   3897    24       3  2019         22       20
# 1         No info   7662     1       5  2019          5       50

# %%
# splitted the arrival time into arrival hours and arrival minutes
# applied the splitting twice as we have to split data with spcae and : as delimeter
df['Arrival_hours'] = df['Arrival_Time'].str.split(" ").str[0].str.split(":").str[0].astype(int)
df['Arrival_Minutes'] = df['Arrival_Time'].str.split(" ").str[0].str.split(":").str[1].astype(int)

# %%
df.head(2)
# Out:
#      Airline    Source Destination  Arrival_Time Duration Total_Stops  \
# 0     IndiGo  Banglore   New Delhi  01:10 22 Mar   2h 50m    non-stop
# 1  Air India   Kolkata    Banglore         13:15   7h 25m     2 stops
#
#   Additional_Info  Price  Days  Months  Year  Dep_hours  Dep_min  \
# 0         No info   3897    24       3  2019         22       20
# 1         No info   7662     1       5  2019          5       50
#
#    Arrival_hours  Arrival_Minutes
# 0              1               10
# 1             13               15

# %%
del df['Arrival_Time']

# %% [markdown]
# # Duration

# %%
df.head(2)
# Out:
#      Airline    Source Destination Duration Total_Stops Additional_Info  \
# 0     IndiGo  Banglore   New Delhi   2h 50m    non-stop         No info
# 1  Air India   Kolkata    Banglore   7h 25m     2 stops         No info
#
#    Price  Days  Months  Year  Dep_hours  Dep_min  Arrival_hours  \
# 0   3897    24       3  2019         22       20              1
# 1   7662     1       5  2019          5       50             13
#
#    Arrival_Minutes
# 0               10
# 1               15

# %%
df['Duration']
# Out:
# 0        2h 50m
# 1        7h 25m
# 2           19h
# 3        5h 25m
# 4        4h 45m
#           ...
# 10678    2h 30m
# 10679    2h 35m
# 10680        3h
# 10681    2h 40m
# 10682    8h 20m
# Name: Duration, Length: 10682, dtype: object

# %%
df['Duration'].unique()
# Out:
# array(['2h 50m', '7h 25m', '19h', '5h 25m', '4h 45m', '2h 25m', '15h 30m',
#        '21h 5m', '25h 30m', '7h 50m', '13h 15m', '2h 35m', '2h 15m',
#        '12h 10m', '26h 35m', '4h 30m', '22h 35m', '23h', '20h 35m',
#        '5h 10m', '15h 20m', '2h 55m', '13h 20m', '15h 10m', '5h 45m',
#        '5h 55m', '13h 25m', '22h', '5h 30m', '10h 25m', '5h 15m',
#        '2h 30m', '6h 15m', '11h 55m', '11h 5m', '8h 30m', '22h 5m',
#        '2h 45m', '12h', '16h 5m', '19h 55m', '3h 15m', '25h 20m', '3h',
#        '16h 15m', '15h 5m', '6h 30m', '25h 5m', '12h 25m', '27h 20m',
#        '10h 15m', '10h 30m', '1h 30m', '1h 25m', '26h 30m', '7h 20m',
#        '13h 30m', '5h', '19h 5m', '14h 50m', '2h 40m', '22h 10m',
#        '9h 35m', '10h', '21h 20m', '18h 45m', '12h 20m', '18h', '9h 15m',
#        '17h 30m', '16h 35m', '12h 15m', '7h 30m', '24h', '8h 55m',
#        '7h 10m', '14h 30m', '30h 20m', '15h', '12h 45m', '10h 10m',
#        '15h 25m', '14h 5m', '20h 15m', '23h 10m', '18h 10m', '16h',
# ...

# %%
# one duration is of 5m so we converted it to 0h 5m as standard form
df['Duration'] = df['Duration'].replace('5m','0h 5m')

# %%
df['Duration'].unique()
# Out:
# array(['2h 50m', '7h 25m', '19h', '5h 25m', '4h 45m', '2h 25m', '15h 30m',
#        '21h 5m', '25h 30m', '7h 50m', '13h 15m', '2h 35m', '2h 15m',
#        '12h 10m', '26h 35m', '4h 30m', '22h 35m', '23h', '20h 35m',
#        '5h 10m', '15h 20m', '2h 55m', '13h 20m', '15h 10m', '5h 45m',
#        '5h 55m', '13h 25m', '22h', '5h 30m', '10h 25m', '5h 15m',
#        '2h 30m', '6h 15m', '11h 55m', '11h 5m', '8h 30m', '22h 5m',
#        '2h 45m', '12h', '16h 5m', '19h 55m', '3h 15m', '25h 20m', '3h',
#        '16h 15m', '15h 5m', '6h 30m', '25h 5m', '12h 25m', '27h 20m',
#        '10h 15m', '10h 30m', '1h 30m', '1h 25m', '26h 30m', '7h 20m',
#        '13h 30m', '5h', '19h 5m', '14h 50m', '2h 40m', '22h 10m',
#        '9h 35m', '10h', '21h 20m', '18h 45m', '12h 20m', '18h', '9h 15m',
#        '17h 30m', '16h 35m', '12h 15m', '7h 30m', '24h', '8h 55m',
#        '7h 10m', '14h 30m', '30h 20m', '15h', '12h 45m', '10h 10m',
#        '15h 25m', '14h 5m', '20h 15m', '23h 10m', '18h 10m', '16h',
# ...

# %%
# created dh as duration of hours and converted it to minutes
df['DH'] =  df['Duration'].str.split(" ").str[0].str.split('h').str[0].astype(int)*60

# %%
# created duration minutes
df['DM'] =  df['Duration'].str.split(" ").str[1].str.split('m').str[0].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3573/3472349519.py in <cell line: 0>()
# ----> 1 df['DM'] =  df['Duration'].str.split(" ").str[1].str.split('m').str[0].astype(int)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
# ...

# %%
# got an error beacuse some data is only present in hours ( eg 28h)
# so we added 0 using fillna so it becomes 28h 0m
df['DM'] =  df['Duration'].str.split(" ").str[1].str.split('m').str[0].fillna(0).astype(int)

# %%
# calculated the total duration now
df['total duration(min)'] = df['DH'] + df['DM']

# %%
del df['DH']
del df['DM']
del df['Duration']

# %%
df.head()
# Out:
#        Airline    Source Destination Total_Stops Additional_Info  Price  Days  \
# 0       IndiGo  Banglore   New Delhi    non-stop         No info   3897    24
# 1    Air India   Kolkata    Banglore     2 stops         No info   7662     1
# 2  Jet Airways     Delhi      Cochin     2 stops         No info  13882     9
# 3       IndiGo   Kolkata    Banglore      1 stop         No info   6218    12
# 4       IndiGo  Banglore   New Delhi      1 stop         No info  13302     1
#
#    Months  Year  Dep_hours  Dep_min  Arrival_hours  Arrival_Minutes  \
# 0       3  2019         22       20              1               10
# 1       5  2019          5       50             13               15
# 2       6  2019          9       25              4               25
# 3       5  2019         18        5             23               30
# 4       3  2019         16       50             21               35
#
#    total duration(min)
# 0                  170
# 1                  445
# ...

# %%
del df['Additional_Info']

# %%
df.head()
# Out:
#        Airline    Source Destination Total_Stops  Price  Days  Months  Year  \
# 0       IndiGo  Banglore   New Delhi    non-stop   3897    24       3  2019
# 1    Air India   Kolkata    Banglore     2 stops   7662     1       5  2019
# 2  Jet Airways     Delhi      Cochin     2 stops  13882     9       6  2019
# 3       IndiGo   Kolkata    Banglore      1 stop   6218    12       5  2019
# 4       IndiGo  Banglore   New Delhi      1 stop  13302     1       3  2019
#
#    Dep_hours  Dep_min  Arrival_hours  Arrival_Minutes  total duration(min)
# 0         22       20              1               10                  170
# 1          5       50             13               15                  445
# 2          9       25              4               25                 1140
# 3         18        5             23               30                  325
# 4         16       50             21               35                  285

# %% [markdown]
# # Compare the mean price of every airline

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mean_price = df.groupby('Airline')['Price'].mean()
plt.figure(figsize = (10,5))
sns.barplot(x = mean_price.index , y = mean_price.values)
# Out:
# <Axes: xlabel='Airline'>

# %%
# Average price vs number of stops
mean_price_stops = df.groupby('Total_Stops')['Price'].mean()
mean_price_stops
# Out:
# Total_Stops
# 1 stop      10594.123556
# 2 stops     12715.807895
# 3 stops     13112.000000
# 4 stops     17686.000000
# non-stop     5024.900315
# Name: Price, dtype: float64

# %%
# duration vs price
